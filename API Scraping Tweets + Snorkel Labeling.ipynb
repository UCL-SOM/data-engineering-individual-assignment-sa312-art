# %% [markdown]
# # API Scraping

# %%
#import libraries
import requests
import json

# %%
#headers function
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
#define the access keys 
aws_access_key_id= "ASIA2I2V2ZOFYA45LEYC"
aws_secret_access_key= "6fvRhRJtWha6075DRuWdW+KuybWepvME9hd1DRGd"
aws_session_token="..."

# %%
#function to set the rules to filter the live stream of tweets
def set_rules(headers, sample_rules):
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

# %%
# Let's set the code to get the stream of tweets
def get_stream(headers, max_number_tweets):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    counter_tweets = 0
    stream_tweets = {'stream_tweets':[]}

    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            stream_tweets["stream_tweets"].append(json_response)

            print(json.dumps(json_response, indent=4, sort_keys=True))
            counter_tweets += 1

            if counter_tweets >= max_number_tweets:
                with open("stream_tweets.json", 'w') as f:
                    json.dump(stream_tweets, f, indent=4)

                # Close the stream of tweets
                response.close()
                
                # Break the loop
                break

# %%
# Let's call all the functions
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAA%2FwOQEAAAAAgP1qA27vDaOuOB%2Fwl%2FC7yJqi5lU%3Da5aW8ClszLCM2MDdAsdLGbiCGYBs78yyXzlb34w062lf8jpAlz'

# Creat the headers for the HTTP request
headers = create_headers(bearer_token)

# Set the rules for the filtering of tweets that mention vaccines/vaccination/transperancy/efficiacy
# We are setting to get only the tweets in English and exclduing retweets
sample_rules = [
    {"value": " (vaccine OR vaccination OR vaccinated ) lang:en -is:retweet"},
    {"value": " (transperancy OR efficacy) lang:en -is:retweet"},
]

set_rules = set_rules(headers, sample_rules)

# Get the stream of tweets live
max_number_tweets = 50
get_stream(headers, max_number_tweets)
# Out:
# {"data": [{"value": " (vaccine OR vaccination OR vaccinated ) lang:en -is:retweet", "id": "1381014967101620226"}, {"value": " (transperancy OR efficacy) lang:en -is:retweet", "id": "1381014967101620225"}], "meta": {"sent": "2021-04-10T22:43:21.860Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1381014933706526725",
#         "text": "I got the same vaccine shot @MariahCarey got the Fake one"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014934469885963",
#         "text": "OMFGGGG TWT IS THHE DUMBEST APP https://t.co/HrferM3ImM"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014935434625024",
#         "text": "@BabsR10 My husband and I received the first Pfizer vaccine; get second one April 16th.  My arm was sore.  That\u2019s it.  My husband had no side effects at all."
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014935887622147",
#         "text": "Another quackcine... https://t.co/ZqAKzLSZOs"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014936256536576",
#         "text": "Nobody is going to boycott the Yankees or the Mets. More and more business require proof of vaccination from employees. Customers are next. This is the rollout.\n\nI, for one, will never buy a product from a store that requires proof of vaccination. I hope you will join me in this."
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014936101457921",
#         "text": "\u201cUnexpectedly\u201d why are people overlooking the fact that this man was 99 with a heart condition. I\u2019m so over these anti vaxxers https://t.co/4cM1Ng89Ka https://t.co/NSObvKUjDr"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014936789323781",
#         "text": "@Edwards4Dermot I\u2019m fully vaccinated.... waiting for the kids to get vaccinated.... hopefully in the summer"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014938244636673",
#         "text": "@jscutiger The first clinical trial patients have had the vaccine for more than a year at this point. No side effects for any vaccine have *ever* been found to occur more than 6 months after inoculation."
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381

#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014981630566400",
#         "text": "@misst0pia @Cazzy @MsYouDoYou on the current pace of ~40,000 vaxxes a day, we are on pace to have every eligible person in british columbia vaccinated by july 1st"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014982146420736",
#         "text": "#Vaccine appts available at Rite Aid in: Kingston (Ulster), Kingston (Flatbush), Hyde Park, Poughkeepsie (Hooker), Poughkeepsie (North Rd), Colonie, Clifton Park, Amsterdam, Gloversville, Syracuse, N Syracuse, Baldwinsville, Cortland, New Hartford, Utica, Newark, Massena,..."
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014982981152770",
#         "text": "@GlobalBC I guess the expired ones were not used due to so many appointments not being taken.\nSays this is being kept quiet, is happening across the country, I will be one of them for now.\nhttps://t.co/GklgcGW4AP"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014983329210370",
#         "text": "@ozhomeschool There should be no vaccine passports anywhere for any reason."
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1381014984663109636",
#         "text": "@Emily_Burns_V When an volcano erupts, who in their right minds thinks of grabbing their vaccination card before running for their life? #stvincentvolcano"
#     },
#     "matching_rules": [
#         {
#             "id": 1381014967101620226,
#             "tag": null
#         },
#         {
#             "id": 1381013913626677251,
#             "tag": null
#         }
#     ]
# }

# %%
# load data using Python JSON module
with open('/project/stream_tweets.json','r') as f:
    data = json.loads(f.read())
# Flatten data because nested list is put up into a single stream_tweets.
df = pd.json_normalize(data, record_path =['stream_tweets'])
df.drop('matching_rules', axis =1,  inplace =True)
df = df.rename(columns={"data.id": "id", "data.text": "text"})
df
# Out:
#                      id                                               text
# 0   1381014933706526725  I got the same vaccine shot @MariahCarey got t...
# 1   1381014934469885963  OMFGGGG TWT IS THHE DUMBEST APP https://t.co/H...
# 2   1381014935434625024  @BabsR10 My husband and I received the first P...
# 3   1381014935887622147       Another quackcine... https://t.co/ZqAKzLSZOs
# 4   1381014936256536576  Nobody is going to boycott the Yankees or the ...
# 5   1381014936101457921  “Unexpectedly” why are people overlooking the ...
# 6   1381014936789323781  @Edwards4Dermot I’m fully vaccinated.... waiti...
# 7   1381014938244636673  @jscutiger The first clinical trial patients h...
# 8   1381014940547309568  @SkyNewsAust SIDE EFFECTS: *every* vaccine has...
# 9   1381014943470739457  @rperly1 We are both fully vaccinated so the g...
# 10  1381014945001791491  @suss2hyphens agreed.  I also wonder if any te...
# 11  1381014944951513101            Caption contest https://t.co/DIMin0tgTZ
# 12  1381014947061096448  @FuroridaNoMaya \n\nWhen you see it....\n\nhtt...
# 13  1381014947937804290   I’m now fully vaccinated https://t.co/NdB09ygmsJ
# 14  1381014948948611072  This is the media trying to claw back credibil...
# 15  1381014950093725701  Vaccine hesitancy among minority groups have b...
# 16  1381014951041642498  Killing Liberty: Could Vaccine Resisters Be WA...
# 17  1381014952438206468  Yeah, he’s a real brain trust. https://t.co/Y2...
# 18  1381014952996179974  YES! I am so happy for you Kate!!!❤️❤️❤️ https...
# 19  1381014954124451841  sorry for tweeting so much today, i had to sta...
# 20  1381014954757615617  @CalamityJayne4 It will probably get above tha...
# 21  1381014957253402630  @mjansen22598292 @AhDebit @GregAbbott_TX I've ...
# 22  1381014956188041221  Congratulations to @WTFDLANCERSOFT1 on a great...
# 23  1381014960474619905  Being vaccinated does NOT mean it’s ok to call...
# 24  1381014960046661634  @ianaIexander Follow me for COVID vaccine appo...
# 25  1381014962454327300  @xekhkl @jameshamblin Insurance pays for the a...
# 26  1381014962538172422  @UConnMeg22 Yeah, I really think having the an...
# 27  1381014963100151809  Vaccine 1/2 complete! So far no reaction. Look...
# 28  1381014963632758786  @GVendacopy @polk_bruno @CBCNews I told you I ...
# 29  1381014964396232707  Everyone in the post-vaccine waiting area has ...
# 30  1381014965440614412  @TradeOnTheWire1 Like cause of covid? As long ...
# 31  1381014967659294722  Starting next Thursday, you will either need t...
# 32  1381014968125038598       @VictorPopeJr 2 weeks? It wasn’t the vaccine
# 33  1381014969047736321  @Lotx Well it’s ostensibly to prove your vacci...
# 34  1381014968468787204  “the health dep has repeatedly refused to tell...
# 35  1381014971488813057  Where do we send the flowers for them https://...
# 36  1381014974512910346  @DigressIBut @johnsmi55266544 @twentee7 @TomiL...
# 37  1381014972914802693  I was a huge Trump Supporter, but always was e...
# 38  1381014974722637824  The UK's approach to vaccine safety has been f...
# 39  1381014976261918732  At a vaccine center ..and I'm pleased to see t...
# 40  1381014977067286532  One of the DNA gene therapy injections is made...
# 41  1381014978308759555  @SnottieDrippen It was all the racism and ince...
# 42  1381014979135082499  @cnni Someone needs to remind them that Genera...
# 43  1381014979327954944  @jameshamblin That is my response to people wh...
# 44  1381014981223849985  @radiobeast66 Add Ontario's mass vaccination c...
# 45  1381014981630566400  @misst0pia @Cazzy @MsYouDoYou on the current p...
# 46  1381014982146420736  #Vaccine appts available at Rite Aid in: Kings...
# 47  1381014982981152770  @GlobalBC I guess the expired ones were not us...
# 48  1381014983329210370  @ozhomeschool There should be no vaccine passp...
# 49  1381014984663109636  @Emily_Burns_V When an volcano erupts, who in ...

# %%
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAA%2FwOQEAAAAAgP1qA27vDaOuOB%2Fwl%2FC7yJqi5lU%3Da5aW8ClszLCM2MDdAsdLGbiCGYBs78yyXzlb34w062lf8jpAlz'

query = ("EU Medicines Agency", "World Health Organization (WHO)")
max_results = 50

# Prepare the headers to pass the authentication to Twitter's api
headers = {
    'Authorization': 'Bearer {}'.format(bearer_token),
}

params = (
    ('query', query),
    ('max_results', str(int(max_results))), # Let's make sure that the number is an string
)

# Does the request to get the most recent tweets
response = requests.get('https://api.twitter.com/2/tweets/search/recent', headers=headers, params=params)

# Validates that the query was successful
if response.status_code == 200:
    print("URL of query:", response.url)
    
    # Let's convert the query result to a dictionary that we can iterate over
    tweets =  json.loads(response.text) 
    print("Total number of most recent tweets: ", len(tweets['data']))
          
    for tweet in tweets['data']:
        print("tweet_id: ", tweet['id'], "tweet_text: ", tweet['text'])

# %%
import json
# load data using Python JSON module
with open('/project/twitterQuery.json','r') as f:
    data_1 = json.loads(f.read())
# Flatten data
df_1 = pd.json_normalize((data_1), record_path =['data'])
# 43  1380982668737839106  World Health Organization Director-General Ted...
# 44  1380980593010352131  RT @ERACoalition: The World Health Organizatio...
# 45  1380977247138541575  @SusanStJames3_ @PhillipsNanl WHO. \n\n"Gates ...
# 46  1380973749923573761  RT @CGTNOfficial: The vast majority of COVID-1...
# 47  1380971561256095746  RT @CGTNEurope: The World Health Organization ...
# 48  1380971376853577728  RT @FOX9: Wealthy countries have received the ...
# 49  1380970878943563782  RT @PDChina: Wealthier countries have received...

# %%
final_result = df.append([df_1])
final_result.head(25)
# Out:
#                      id                                               text
# 0   1381014933706526725  I got the same vaccine shot @MariahCarey got t...
# 1   1381014934469885963  OMFGGGG TWT IS THHE DUMBEST APP https://t.co/H...
# 2   1381014935434625024  @BabsR10 My husband and I received the first P...
# 3   1381014935887622147       Another quackcine... https://t.co/ZqAKzLSZOs
# 4   1381014936256536576  Nobody is going to boycott the Yankees or the ...
# 5   1381014936101457921  “Unexpectedly” why are people overlooking the ...
# 6   1381014936789323781  @Edwards4Dermot I’m fully vaccinated.... waiti...
# 7   1381014938244636673  @jscutiger The first clinical trial patients h...
# 8   1381014940547309568  @SkyNewsAust SIDE EFFECTS: *every* vaccine has...
# 9   1381014943470739457  @rperly1 We are both fully vaccinated so the g...
# 10  1381014945001791491  @suss2hyphens agreed.  I also wonder if any te...
# 11  1381014944951513101            Caption contest https://t.co/DIMin0tgTZ
# 12  1381014947061096448  @FuroridaNoMaya \n\nWhen you see it....\n\nhtt...
# 13  1381014947937804290   I’m now fully vaccinated https://t.co/NdB09ygmsJ
# 14  1381014948948611072  This is the media trying to claw back credibil...
# 15  1381014950093725701  Vaccine hesitancy among minority groups have b...
# 16  1381014951041642498  Killing Liberty: Could Vaccine Resisters Be WA...
# 17  1381014952438206468  Yeah, he’s a real brain trust. https://t.co/Y2...
# 18  1381014952996179974  YES! I am so happy for you Kate!!!❤️❤️❤️ https...
# 19  1381014954124451841  sorry for tweeting so much today, i had to sta...
# 20  1381014954757615617  @CalamityJayne4 It will probably get above tha...
# 21  1381014957253402630  @mjansen22598292 @AhDebit @GregAbbott_TX I've ...
# 22  1381014956188041221  Congratulations to @WTFDLANCERSOFT1 on a great...
# 23  1381014960474619905  Being vaccinated does NOT mean it’s ok to call...
# 24  1381014960046661634  @ianaIexander Follow me for COVID vaccine appo...

# %% [markdown]
# # Snorkel - Creating Labels

# %%
#install snorkel
#!pip install snorkel
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# Collecting snorkel
#   Downloading snorkel-0.9.7-py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 24.4 MB/s eta 0:00:01
# Collecting networkx<2.4,>=2.2
#   Downloading networkx-2.3.zip (1.7 MB)
#      |████████████████████████████████| 1.7 MB 43.3 MB/s eta 0:00:01
# Collecting tensorboard<2.0.0,>=1.14.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 76.4 MB/s eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.33.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from snorkel) (4.47.0)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from snorkel) (1.0.5)
# Requirement already satisfied: numpy<1.20.0,>=1.16.5 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from snorkel) (1.18.5)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.20.2 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from snorkel) (0.23.1)
# Collecting torch<2.0.0,>=1.2.0
#   Downloading torch-1.8.1-cp38-cp38-manylinux1_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 3.1 kB/s  eta 0:00:011
# Collecting munkres>=1.0.6
#   Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from snorkel) (1.5.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from networkx<2.4,>=2.2->snorkel) (4.4.2)
# Requirement already satisfied: grpcio>=1.6.3 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (1.33.2)
# Requirement already satisfied: absl-py>=0.4 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (0.11.0)
# Requirement already satisfied: six>=1.10.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (3.13.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (3.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (49.2.0.post20200714)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (0.34.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from tensorboard<2.0.0,>=1.14.0->snorkel) (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.0.0->snorkel) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.0.0->snorkel) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from scikit-learn<0.25.0,>=0.20.2->snorkel) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from scikit-learn<0.25.0,>=0.20.2->snorkel) (2.1.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from torch<2.0.0,>=1.2.0->snorkel) (3.7.4.2)
# Building wheels for collected packages: networkx
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1555989 sha256=dfce1afc7616343985fbd7db47cf8ae678578569725c63e756743c8c2c431bdb
#   Stored in directory: /home/faculty/.cache/pip/wheels/ff/62/9e/0ed2d25fd4f5761e2d19568cda0c32716556dfa682e65ecf64
# Successfully built networkx
# ERROR: tensorflow 2.3.1 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 1.15.0 which is incompatible.
# Installing collected packages: networkx, tensorboard, torch, munkres, snorkel
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.4
#     Uninstalling networkx-2.4:
#       Successfully uninstalled networkx-2.4
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
# Successfully installed munkres-1.1.4 networkx-2.3 snorkel-0.9.7 tensorboard-1.15.0 torch-1.8.1

# %%
#import required libraries
from snorkel.labeling import LabelingFunction
import re
from snorkel.preprocess import preprocessor
from textblob import TextBlob
from snorkel.labeling import PandasLFApplier
from snorkel.labeling.model import LabelModel
from snorkel.labeling import LFAnalysis
from snorkel.labeling import filter_unlabeled_dataframe

# %%
#define constants to represent the class labels :official, not_official
ABSTAIN = -1
OFFICIAL = 0
NOT_OFFICIAL = 1
#define function which looks into the input words 
def keyword_lookup(x, keywords, label):
    if any(word in x.text.lower() for word in keywords):
        return label
    return ABSTAIN
#define function which assigns a correct label
def make_keyword_lf(keywords, label=OFFICIAL):
    return LabelingFunction(
        name=f"keyword_{keywords[0]}",
        f=keyword_lookup,
        resources=dict(keywords=keywords, label=label),
    )

#determine the Snorkel wording requirements 
""" Official tweets contain word 'cases' """
keyword_cases = make_keyword_lf(keywords=["cases"])

"""Official tweets contain word vaccines or vaccinated or vaccination"""
keyword_vaccine = make_keyword_lf(keywords=["vaccines", "vaccinated", "vaccination"])

"""Official tweets contain word 'pandemic' """
keyword_pandemic = make_keyword_lf(keywords=["pandemic"])

"""Official tweets contain word 'covid' """
keyword_covid = make_keyword_lf(keywords=["covid"])

"""Official tweets contain word 'death' """
keyword_death = make_keyword_lf(keywords=["death"])

"""Official tweets contain word 'government' """
keyword_gov = make_keyword_lf(keywords=["government"])

"""Official tweets contain word 'infection' """
keyword_infection = make_keyword_lf(keywords=["infection"])

"""Official tweets contain word 'jab' """
keyword_jab = make_keyword_lf(keywords=["jab"])

"""Official tweets contain word 'quarantine' """
keyword_quarntine = make_keyword_lf(keywords=["quarantine"])

"""Official tweets contain word 'side effects' """
keyword_effect = make_keyword_lf(keywords=["side effects"])

"""Official tweets contain word 'scientists' """
keyword_scientists = make_keyword_lf(keywords=["scientists"])

"""Official tweets contain word 'medical' """
keyword_medical = make_keyword_lf(keywords=["medical"])

"""Official tweets contain word 'efficacy' """
keyword_efficacy = make_keyword_lf(keywords=["efficacy"])

"""Unofficial tweets usually contain word subscribe"""
keyword_subscribe = make_keyword_lf(keywords=["subscribe"], label=NOT_OFFICIAL)

"""Unofficial tweets usually contain word http which links to another advertisment"""
keyword_http = make_keyword_lf(keywords=["http"], label=NOT_OFFICIAL)

# %%
#define a function which differentiates tweets based on length (number of words)
@labeling_function()
def long_tweet(x):
    """Official tweets are often long, such as"""
    return OFFICIAL if len(x.text.split()) > 6 else ABSTAIN

#use a regular expression to determine tweets that make reference to a number of cases
@labeling_function()
def regex_cases_rise(x):
    return OFFICIAL if re.search(r"cases.*rise.*[0-9]+", x.text, flags=re.I) else ABSTAIN

@labeling_function()
def regex_cases_now(x):
    return OFFICIAL if re.search(r"cases.*now", x.text, flags=re.I) else ABSTAIN

# %%
#install textlob
#!pip install textblob
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# Requirement already satisfied: textblob in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from textblob) (3.5)
# Requirement already satisfied: tqdm in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (4.47.0)
# Requirement already satisfied: click in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: joblib in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (0.16.0)
# Requirement already satisfied: regex in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (2020.6.8)

# %%
#set up a preprocessor function to determine polarity & subjectivity 
@preprocessor(memoize=True)
def textblob_sentiment(x):
    scores = TextBlob(x.text)
    x.polarity = scores.sentiment.polarity
    x.subjectivity = scores.sentiment.subjectivity
    return x
#find polarity
@labeling_function(pre=[textblob_sentiment])
def textblob_polarity(x):
    return OFFICIAL if x.polarity > 0.9 else ABSTAIN
#find subjectivity 
@labeling_function(pre=[textblob_sentiment])
def textblob_subjectivity(x):
    return OFFICIAL if x.subjectivity >= 0.5 else ABSTAIN

# %%
#combine all the labeling functions 
lfs = [keyword_cases, keyword_vaccine, keyword_pandemic, keyword_covid, keyword_death, keyword_gov,
       keyword_infection, keyword_medical, keyword_scientists, keyword_efficacy, keyword_jab,
       keyword_effect, keyword_quarntine,
       keyword_subscribe, keyword_http, long_tweet, 
       regex_cases_rise, regex_cases_now, textblob_polarity, textblob_subjectivity]

# %%
#apply the lfs on the dataframe
applier = PandasLFApplier(lfs=lfs)
L_snorkel = applier.apply(df=final_result)
# Out:
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 100/100 [00:00<00:00, 920.08it/s]

# %%
#apply the label model
label_model = LabelModel(cardinality=2, verbose=True)
#fit on the data
label_model.fit(L_snorkel, n_epochs=500, log_freq=100, seed=123)
#predict and create the labels
final_result["label"] = label_model.predict(L=L_snorkel, tie_break_policy="Abstain")

# %%
#determine the labeling analysis
LFAnalysis(L_snorkel, lfs).lf_summary()
# Out:
#                         j Polarity  Coverage  Overlaps  Conflicts
# keyword_cases           0       []      0.00      0.00       0.00
# keyword_vaccines        1      [1]      0.23      0.23       0.03
# keyword_pandemic        2      [1]      0.20      0.20       0.04
# keyword_covid           3      [1]      0.22      0.22       0.05
# keyword_death           4      [1]      0.01      0.01       0.00
# keyword_government      5      [1]      0.06      0.06       0.04
# keyword_infection       6       []      0.00      0.00       0.00
# keyword_medical         7      [1]      0.04      0.04       0.03
# keyword_scientists      8      [1]      0.16      0.16       0.01
# keyword_efficacy        9      [1]      0.01      0.01       0.00
# keyword_jab            10      [1]      0.02      0.02       0.02
# keyword_side effects   11      [1]      0.03      0.03       0.01
# keyword_quarantine     12       []      0.00      0.00       0.00
# keyword_subscribe      13       []      0.00      0.00       0.00
# keyword_http           14      [0]      0.36      0.33       0.33
# long_tweet             15      [1]      0.96      0.85       0.32
# regex_cases_rise       16       []      0.00      0.00       0.00
# regex_cases_now        17       []      0.00      0.00       0.00
# textblob_polarity      18       []      0.00      0.00       0.00
# textblob_subjectivity  19      [1]      0.40      0.40       0.16

# %%
#determine the probabilities
probs_train = label_model.predict_proba(L=L_snorkel)
#find the final dataframe with labels (0,1)
df_filtered, probs_filtered = filter_unlabeled_dataframe(X= final_result, y=probs_train,
L=L_snorkel)

# %%
#inspect the final dataframe 
df_filtered
# Out:
#                      id                                               text  \
# 0   1381014933706526725  I got the same vaccine shot @MariahCarey got t...
# 1   1381014934469885963  OMFGGGG TWT IS THHE DUMBEST APP https://t.co/H...
# 2   1381014935434625024  @BabsR10 My husband and I received the first P...
# 3   1381014935887622147       Another quackcine... https://t.co/ZqAKzLSZOs
# 4   1381014936256536576  Nobody is going to boycott the Yankees or the ...
# ..                  ...                                                ...
# 45  1380977247138541575  @SusanStJames3_ @PhillipsNanl WHO. \n\n"Gates ...
# 46  1380973749923573761  RT @CGTNOfficial: The vast majority of COVID-1...
# 47  1380971561256095746  RT @CGTNEurope: The World Health Organization ...
# 48  1380971376853577728  RT @FOX9: Wealthy countries have received the ...
# 49  1380970878943563782  RT @PDChina: Wealthier countries have received...
#
#     label
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ..    ...
# 45      0
# 46      0
# 47      0
# 48      0
# 49      0
#
# [100 rows x 3 columns]

# %%
#get the label counts 
df_filtered['label'].value_counts()
# Out:
# 0    69
# 1    31
# Name: label, dtype: int64

# %%
#create a csv file to be used in the further analysis
df_filtered.to_csv('Tweets.csv')
